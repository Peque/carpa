# %% [markdown]
# Algo de configuración antes de pintar gráficos:

# %%
# %matplotlib inline

import matplotlib

matplotlib.pyplot.style.use('seaborn')

# %% [markdown]
# Algo de código:

# %%
import pandas

data = pandas.read_csv('data.csv', names=['variable', 'timestamp', 'value'], index_col=0)
data[data['variable'] == 'h'].plot(x='timestamp', y='value')
